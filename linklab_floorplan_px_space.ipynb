# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from pathlib import Path
from PIL import Image # use the python image library
from collections import defaultdict

# %%
filepath = Path("building_plan/floorplan_geometry.png")
img = Image.open(filepath)

plt.figure(figsize = (26,13))
plt.xticks(range(0,1110,50))
plt.yticks(range(0,564,50))

plt.imshow(img)
plt.show()

# %%
filepath = Path("building_plan/floorplan_geometry.png")
img = Image.open(filepath)

plt.figure(figsize = (26,13))
plt.xticks(range(0,1110,50))
plt.yticks(range(0,564,50))


# Awair-Onmi: to draw a point on co-ordinate (200,300)
points = [
    (403,39)  , (170,318) , (575,282), (412,282), (12,134) , (581,188), (618,175), (709,204) , (709,204), (647,175) ,
    (623,220) , (692,124) , (673,175), (692,124), (148,385), (709,146), (709,146), (581,146) , (581,214), (581,188) ,
    (984,274) , (863,157) , (897,260), (701,89) , (788,44) , (1014,11), (836,119), (1038,154), (880,322), (1076,139),
    (1105,388), (1069,477), (888,544), (807,529), (173,518), (205,518), (222,543), (222,517) , (128,557), (10,482),
    (402,492)
    
]

x = list(map(lambda x: x[0], points))
y = list(map(lambda x: x[1], points))
plt.scatter(x, y, color = 'red', s=200, label = f"Awair-Onmi: {len(points)}")

# # Awair-Sensor: to draw a point on co-ordinate (200,300)
points = [(738,421), (584,173), (371,322), (852,44), (991,474), (383,304), (657,39), (215,33) ]

x = list(map(lambda x: x[0], points))
y = list(map(lambda x: x[1], points))
plt.scatter(x, y, color = 'blue', s=200, label=f"Awair-Sensor: {len(points)}")

# plt.grid(True)

# for xy in zip(x, y):
#     plt.annotate('(%.0f, %.0f)' % xy, xy=xy, color='green', fontsize=20)

#     plt.annotate(f'({x},{y}) {des[0]}', xy=xy, color='red', fontsize=20)

plt.imshow(img)
plt.xlim([0, 1110])
plt.ylim([564, 0])

plt.legend(loc = 'upper left')
plt.title('linklab pixel coordinate')
plt.xlabel('Pixel x')
plt.ylabel('Pixel Y')

plt.show()
